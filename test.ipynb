# %% [markdown]
# ## Merge all the trails

# %%
import json

# %%
import pandas as pd
import os
import json

def merge_csv_by_columns(folder_path, output_file):
    # List all CSV files in the folder
    csv_files = [file for file in os.listdir(folder_path) if file.endswith('.csv')]

    # Initialize an empty list to store DataFrames
    dataframes = []

    # Read each CSV file and append it to the list
    for file in csv_files:
        df = pd.read_csv(os.path.join(folder_path, file))
        dataframes.append(df)

    # Merge all DataFrames based on common column names
    merged_df = pd.concat(dataframes, ignore_index=True, sort=False)

    # Remove rows where 'location' is empty
    # merged_df = merged_df.dropna(subset=['Locations'])

    # Remove duplicate rows
    merged_df = merged_df.drop_duplicates()

    # Save the merged DataFrame to a new CSV file
    merged_df.to_csv(output_file, index=False)

    return merged_df

# Example usage
folder_path = './trials/'
output_file = 'merged_output.csv'
clinical_trails_data = merge_csv_by_columns(folder_path, output_file)

# %%
clinical_trails_data.head(5)
# Out:
#     NCT Number                                        Study Title  \
# 0  NCT03334747  Safety of KAE609 in Adults With Uncomplicated ...
# 1  NCT01190202  Epidemiology Study of Malaria Transmission Int...
# 2  NCT01955382  Evaluation of Oral Activated Charcoal on Antim...
# 3  NCT01465048  Optimisation of Controlled Human Malaria Infec...
# 4  NCT02458092  Evaluate the Safety and Efficacy of Plasmodium...
#
#                                       Study URL Acronym Study Status  \
# 0  https://clinicaltrials.gov/study/NCT03334747     NaN    COMPLETED
# 1  https://clinicaltrials.gov/study/NCT01190202     NaN    COMPLETED
# 2  https://clinicaltrials.gov/study/NCT01955382     NaN    COMPLETED
# 3  https://clinicaltrials.gov/study/NCT01465048     NaN    COMPLETED
# 4  https://clinicaltrials.gov/study/NCT02458092     NaN    COMPLETED
#
#                                        Brief Summary Study Results  \
# 0  KAE609 will be evaluated primarily for hepatic...           YES
# 1  The aim of this epidemiology study is to chara...           YES
# 2  Background:\n\n- Malaria is caused by small pa...           YES
# 3  This is an open label, human pilot study to op...           YES
# 4  The purpose of this study is to determine whet...           YES
#
#                       Conditions  \
# 0                        Malaria
# 1       Malaria|Malaria Vaccines
# 2         Malaria|Severe Malaria
# 3  Malaria|Plasmodium Falciparum
# 4                        Malaria
#
#                                        Interventions  \
# 0                         DRUG: KAE609|DRUG: Coartem
# 1  PROCEDURE: Blood sampling|PROCEDURE: Assessmen...
# 2  DRUG: Actidose Aqua|DRUG: Artesunate|DRUG: Amo...
# 3  BIOLOGICAL: Plasmodium falciparum sporozoites ...
# 4  BIOLOGICAL: Plasmodium falciparum Malaria Prot...
#
#                             Primary Outcome Measures  ...  \
# 0  Number of Participants With at Least 2 CTCAE G...  ...
# 1  Number of Subjects With Plasmodium Falciparum ...  ...
# 2  Parasite Clearance Half-life, To compare paras...  ...
# 3  Number of Participants Infected, To determine ...  ...
# 4  Number of Participants With Solicited Adverse ...  ...
#
#                                         Study Design  \
# 0  Allocation: RANDOMIZED|Intervention Model: PAR...
# 1  Allocation: NA|Intervention Model: SINGLE_GROU...
# 2  Allocation: RANDOMIZED|Intervention Model: PAR...
# 3  Allocation: NON_RANDOMIZED|Intervention Model:...
# 4  Allocation: RANDOMIZED|Intervention Model: PAR...
#
#                          Other IDs  Start Date Primary Completion Date  \
# 0       CKAE609A2202|207813/Z/17/Z  2017-11-16              2019-11-23
# 1                           114001  2011-03-14              2013-12-20
# 2  999913209|13-I-N209|NCT01955382     2013-09                 2015-07
# 3                           VAC049     2011-10                 2012-02
# 4             A-14620.b|WRAIR 1417     2008-04                 2008-12
#
#   Completion Date First Posted Results First Posted  Last Update Posted  \
# 0      2019-11-23   2017-11-07           2020-09-03          2021-10-11
# 1      2013-12-20   2010-08-27           2017-09-29          2020-08-18
# 2         2015-07   2013-10-07           2017-04-20          2018-02-06
# 3         2013-02   2011-11-04           2013-04-08          2013-06-24
# 4         2009-06   2015-05-29           2018-11-07          2023-06-28
#
#                                            Locations  \
# 0  Novartis Investigative Site, Lambarene, Gabon|...
# 1  GSK Investigational Site, Ouagadougou 01, Burk...
# 2  Universite des Sciencies, Techniques et Techno...
# 3  Centre for Clinical Vaccinology and Tropical M...
# 4                                                NaN
#
#                                      Study Documents
# 0  Study Protocol, https://storage.googleapis.com...
# 1                                                NaN
# 2  Study Protocol and Statistical Analysis Plan, ...
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Preprocess the data

# %%
def preprocess(df):
    for col in df.columns:
        if df[col].dtype == object:
            df[col] = df[col].str.lower()
        df[col] = df[col].fillna('')
    return df

# %%
import pandas as pd
file_path = r'Data/merged_output.csv'
df_clinical = pd.read_csv(file_path)
preprocessed_trials = preprocess(df_clinical)

preprocessed_trials.head()
# Out:
#     NCT Number                                        Study Title  \
# 0  nct03334747  safety of kae609 in adults with uncomplicated ...
# 1  nct01190202  epidemiology study of malaria transmission int...
# 2  nct01955382  evaluation of oral activated charcoal on antim...
# 3  nct01465048  optimisation of controlled human malaria infec...
# 4  nct02458092  evaluate the safety and efficacy of plasmodium...
#
#                                       Study URL Acronym Study Status  \
# 0  https://clinicaltrials.gov/study/nct03334747            completed
# 1  https://clinicaltrials.gov/study/nct01190202            completed
# 2  https://clinicaltrials.gov/study/nct01955382            completed
# 3  https://clinicaltrials.gov/study/nct01465048            completed
# 4  https://clinicaltrials.gov/study/nct02458092            completed
#
#                                        Brief Summary Study Results  \
# 0  kae609 will be evaluated primarily for hepatic...           yes
# 1  the aim of this epidemiology study is to chara...           yes
# 2  background:\n\n- malaria is caused by small pa...           yes
# 3  this is an open label, human pilot study to op...           yes
# 4  the purpose of this study is to determine whet...           yes
#
#                       Conditions  \
# 0                        malaria
# 1       malaria|malaria vaccines
# 2         malaria|severe malaria
# 3  malaria|plasmodium falciparum
# 4                        malaria
#
#                                        Interventions  \
# 0                         drug: kae609|drug: coartem
# 1  procedure: blood sampling|procedure: assessmen...
# 2  drug: actidose aqua|drug: artesunate|drug: amo...
# 3  biological: plasmodium falciparum sporozoites ...
# 4  biological: plasmodium falciparum malaria prot...
#
#                             Primary Outcome Measures  ...  \
# 0  number of participants with at least 2 ctcae g...  ...
# 1  number of subjects with plasmodium falciparum ...  ...
# 2  parasite clearance half-life, to compare paras...  ...
# 3  number of participants infected, to determine ...  ...
# 4  number of participants with solicited adverse ...  ...
#
#                                         Study Design  \
# 0  allocation: randomized|intervention model: par...
# 1  allocation: na|intervention model: single_grou...
# 2  allocation: randomized|intervention model: par...
# 3  allocation: non_randomized|intervention model:...
# 4  allocation: randomized|intervention model: par...
#
#                          Other IDs  Start Date Primary Completion Date  \
# 0       ckae609a2202|207813/z/17/z  2017-11-16              2019-11-23
# 1                           114001  2011-03-14              2013-12-20
# 2  999913209|13-i-n209|nct01955382     2013-09                 2015-07
# 3                           vac049     2011-10                 2012-02
# 4             a-14620.b|wrair 1417     2008-04                 2008-12
#
#   Completion Date First Posted Results First Posted  Last Update Posted  \
# 0      2019-11-23   2017-11-07           2020-09-03          2021-10-11
# 1      2013-12-20   2010-08-27           2017-09-29          2020-08-18
# 2         2015-07   2013-10-07           2017-04-20          2018-02-06
# 3         2013-02   2011-11-04           2013-04-08          2013-06-24
# 4         2009-06   2015-05-29           2018-11-07          2023-06-28
#
#                                            Locations  \
# 0  novartis investigative site, lambarene, gabon|...
# 1  gsk investigational site, ouagadougou 01, burk...
# 2  universite des sciencies, techniques et techno...
# 3  centre for clinical vaccinology and tropical m...
# 4
#
#                                      Study Documents
# 0  study protocol, https://storage.googleapis.com...
# 1
# 2  study protocol and statistical analysis plan, ...
# 3
# 4
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Convert the CSV data to a JSON-like structure (Updated Code)

# %%
# Re-importing necessary libraries as the execution state was reset
import pandas as pd
import json


# Function to clean unwanted unicode characters like "\u00e9" from a string
def clean_unicode(text):
    if isinstance(text, str):
        return text.encode('ascii', 'ignore').decode('ascii')
    return text

# Updated function to include different intervention types and convert each row to a JSON-like structure
def row_to_json(row):
    trial_info = {
        "Trial ID": clean_unicode(row["NCT Number"]),
        "Title": clean_unicode(row["Study Title"]),
        "URL": clean_unicode(row["Study URL"]),
        "Status": clean_unicode(row["Study Status"]),
        "Brief Summary": clean_unicode(row["Brief Summary"]),
        "Phase": clean_unicode(row["Phases"]),
        "Study Start Date": clean_unicode(row["Start Date"]),
        "Expected Completion Date": clean_unicode(row["Completion Date"])
    }

    # Splitting interventions into different types if they exist
    intervention_types = ["drug", "procedure", "device", "behavioral", "combination_product","biological","radiation","other"]
    interventions_info = {key.capitalize(): [] for key in intervention_types}  # Initialize all intervention types with empty lists
    if pd.notnull(row["Interventions"]):
        interventions = row["Interventions"].split('|')
        for intervention in interventions:
            intervention = intervention.strip()
            for type_key in intervention_types:
                if intervention.startswith(f"{type_key}:"):
                    # Clean the intervention name and add it to the corresponding list
                    intervention_name = intervention[len(f"{type_key}:"):].strip()
                    intervention_cleaned = clean_unicode(intervention_name)
                    # Capitalize the first letter of each intervention type for the output
                    intervention_type_key = type_key.capitalize()
                    interventions_info[intervention_type_key].append(intervention_cleaned)

    # Splitting disease names if multiple diseases are listed
    disease_info = {
        "Disease Name": [clean_unicode(disease) for disease in row["Conditions"].split('|')] if pd.notnull(row["Conditions"]) else []
    }

    # Parsing locations into structured format
    locations_info = []
    if pd.notnull(row["Locations"]):
        locations_list = row["Locations"].split('|')
        for location in locations_list:
            parts = [clean_unicode(part.strip()) for part in location.split(',')]
            location_dict = {
                "Institution": parts[0] if parts else None,
                "City": parts[1] if len(parts) > 1 else None,
                "Country": parts[-1] if parts else None
            }
            locations_info.append(location_dict)

    # Structuring the JSON object
    json_structure = {
        "Trial": trial_info,
        "Drug/Intervention": interventions_info,
        "Disease/Condition": disease_info,
        "Locations": locations_info
    }

    return json_structure

# Convert each row of the dataframe to JSON structure and store in a list
json_data = [row_to_json(row) for index, row in preprocessed_trials.iterrows()]

# Convert the list to JSON string for display
json_string = json.dumps(json_data, indent=4)

# Display the first few JSON structures as a sample
print(json_string[:10000])  # Display only first 2000 characters for brevity
# Out:
# [
#     {
#         "Trial": {
#             "Trial ID": "nct03334747",
#             "Title": "safety of kae609 in adults with uncomplicated plasmodium falciparum malaria.",
#             "URL": "https://clinicaltrials.gov/study/nct03334747",
#             "Status": "completed",
#             "Brief Summary": "kae609 will be evaluated primarily for hepatic safety of single and multiple doses in sequential cohorts with increasing doses.this study aims to determine the maximum safe dose of the investigational drug kae609 in malaria patients.",
#             "Phase": "phase2",
#             "Study Start Date": "2017-11-16",
#             "Expected Completion Date": "2019-11-23"
#         },
#         "Drug/Intervention": {
#             "Drug": [
#                 "kae609",
#                 "coartem"
#             ],
#             "Procedure": [],
#             "Device": [],
#             "Behavioral": [],
#             "Combination_product": [],
#             "Biological": [],
#             "Radiation": [],
#             "Other": []
#         },
#         "Disease/Condition": {
#             "Disease Name": [
#                 "malaria"
#             ]
#         },
#         "Locations": [
#             {
#                 "Institution": "novartis investigative site",
#                 "City": "lambarene",
#                 "Country": "gabon"
#             },
#             {
#                 "Institution": "novartis investigative site",
#                 "City": "kintampo",
#                 "Country": "ghana"
#             },
#             {
#                 "Institution": "novartis investigative site",
#                 "City": "navrango",
#                 "Country": "ghana"
#             },
#             {
#                 "Institution": "novartis investigative site",
#                 "City": "bamako",
#                 "Country": "mali"
#             },
#             {
#                 "Institution": "novartis investigative site",
#                 "City": "sotuba",
#                 "Country": "mali"
#             },
#             {
#                 "Institution": "novartis investigative site",
#                 "City": "kigali",
#                 "Country": "rwanda"
#             },
#             {
#                 "Institution": "novartis investigative site",
#                 "City": "bushenyi",
#                 "Country": "uganda"
#             },
#             {
#                 "Institution": "novartis investigative site",
#                 "City": "kampala",
#                 "Country": "uganda"
#             },
#             {
#                 "Institution": "novartis investigative site",
#                 "City": "tororo",
#                 "Country": "uganda"
#             }
#         ]
#     },
#     {
#         "Trial": {
#             "Trial ID": "nct01190202",
#             "Title": "epidemiology study of malaria transmission intensity in africa",
#             "URL": "https://clinicaltrials.gov/study/nct01190202",
#             "Status": "completed",
#             "Brief Summary": "the aim of this epidemiology study is to characterize in a standardized way malaria transmission intensity at the clinical trial centers participating in study 110021 (nct00866619).",
#             "Phase": "",
#             "Study Start Date": "2011-03-14",
#             "Expected Completion Date": "2013-12-20"
#         },
#         "Drug/Intervention": {
#             "Drug": [],
#             "Procedure": [
#                 "blood sampling",
#                 "assessment of body temperature"
#             ],
#             "Device": [],
#             "Behavioral": [],
#             "Combination_product": [],
#             "Biological": [],
#             "Radiation": [],
#             "Other": []
#         },
#         "Disease/Condition": {
#             "Disease Name": [
#                 "malaria",
#                 "malaria vaccines"
#             ]
#         },
#         "Locations": [
#             {
#                 "Institution": "gsk investigational site",
#                 "City": "ouagadougou 01",
#                 "Country": "burkina faso"
#             },
#             {
#                 "Institution": "gsk investigational site",
#                 "City": "lambarn",
#                 "Country": "gabon"
#             },
#             {
#                 "Institution": "gsk investigational site",
#                 "City": "kintampo",
#                 "Country": "ghana"
#             },
#             {
#                 "Institution": "gsk investigational site",
#                 "City": "kumasi",
#                 "Country": "ghana"
#             },
#             {
#                 "Institution": "gsk investigational site",
#                 "City": "kisumu",
#                 "Country": "kenya"
#             },
#             {
#                 "Institution": "gsk investigational site",
#                 "City": "lilongwe",
#                 "Country": "malawi"
#             },
#             {
#                 "Institution": "gsk investigational site",
#                 "City": "dar-es-salaam",
#                 "Country": "tanzania"
#             },
#             {
#                 "Institution": "gsk investigational site",
#                 "City": "korogwe",
#                 "Country": "tanzania"
#             }
#         ]
#     },
#     {
#         "Trial": {
#             "Trial ID": "nct01955382",
#             "Title": "evaluation of oral activated charcoal on antimalarial drug's ability to kill parasites in malian children with malaria",
#             "URL": "https://clinicaltrials.gov/study/nct01955382",
#             "Status": "completed",
#             "Brief Summary": "background:\n\n- malaria is caused by small parasites carried by some mosquitoes. people can get malaria if an infected mosquito bites them. malaria destroys red blood cells. most malaria is mild, but some children develop severe malaria, which kills about 660,000 people annually. about 9 in 10 who die of malaria are sub-saharan african children, most under 5 years old. scientists can save many lives if they find out how to prevent or relieve severe malaria.\n\nobjective:\n\n- to know if a common medicine called activated charcoal can reduce severe malaria symptoms.\n\neligibility:\n\n- children 2 to 11 years old with mild malaria who live in kenieroba, mali.\n\ndesign:\n\n* for the first 2 days and nights, participants will stay in the hospital.\n* they will have their medical history taken, and a physical exam.\n* blood will be drawn from a thin tube inserted in their hand or forearm. this will be done 3 times overall. a drop of blood will be taken from a finger prick 12 times overall.\n* an antimalarial drug will be injected into the tube in the arm 4 times. each time the drug is given, participants will drink a small cup of either water or activated charcoal.\n* for the following 3 days, participants will take an antimalarial pill.\n* on day 7, participants will visit the hospital. a drop of blood from a finger prick will be tested for malaria parasites.",
#             "Phase": "phase2",
#             "Study Start Date": "2013-09",
#             "Expected Completion Date": "2015-07"
#         },
#         "Drug/Intervention": {
#             "Drug": [
#                 "actidose aqua",
#                 "artesunate",
#                 "amodiaquine"
#             ],
#             "Procedure": [],
#             "Device": [],
#             "Behavioral": [],
#             "Combination_product": [],
#             "Biological": [],
#             "Radiation": [],
#             "Other": []
#         },
#         "Disease/Condition": {
#             "Disease Name": [
#                 "malaria",
#                 "severe malaria"
#             ]
#         },
#         "Locations": [
#             {
#                 "Institution": "universite des sciencies",
#                 "City": "techniques et technologies de bamako",
#                 "Country": "mali"
#             }
#         ]
#     },
#     {
#         "Trial": {
#             "Trial ID": "nct01465048",
#             "Title": "optimisation of controlled human malaria infection using sporozoites administered by needle and syringe",
#             "URL": "https://clinicaltrials.gov/study/nct01465048",
#             "Status": "completed",
#             "Brief Summary": "this is an open label, human pilot study to optimise controlled human malaria infection (chmi) administered by plasmodium falciparum sporozoites (pfspz. volunteers will be inoculated with pfspz challenge. the route of administration and dose will vary in order to identify the optimal regimen that achieves the greatest infection rate in volunteers with plasmodium falciparum. all volunteers recruited will be healthy adults aged between 18 and 45 years. safety and infectivity data will be collected for each of the regimens.",
#             "Phase": "",
#             "Study Start Date": "2011-10",
#             "Expected Completion Date": "2013-02"
#         },
#         "Drug/Intervention": {
#             "Drug": [],
#             "Procedure": [],
#             "Device": [],
#             "Behavioral": [],
#             "Combination_product": [],
#             "Biological": [
#                 "plasmodium falciparum sporozoites 2sites",
#                 "plasmodium falciparum sporozoites 1 site",
#                 "plasmodium falciparum sporozoites 1site"
#             ],
#             "Radiation": [],
#             "Other": []
#         },
#         "Disease/Condition": {
#             "Disease Name": [
#                 "malaria",
#                 "plasmodium falciparum"
#             ]
#         },
#         "Locations": [
#             {
#                 "Institution": "centre for clinical vaccinology and tropical medicine",
#                 "City": "university of oxford",
#                 "Country": "united kingdom"
#             }
#         ]
#     },
#     {
#         "Trial": {
#             "Trial ID": "nct02458092",
#             "Title": "evaluate the safety and efficacy of plasmodium falciparum malaria protein 010 (fmp010) administered with adjuvant as01b",
#             "URL": "https://clinicaltrials.gov/study/nct02458092",
#             "Status": "completed",
#             "Brief Summary": "the purpose of this study is to determine whether an investigational malaria vaccine is safe and induces an immune response against malaria

# %%
json_data = json.loads(json_string)
json_data[0]
# Out:
# {'Trial': {'Trial ID': 'nct03334747',
#   'Title': 'safety of kae609 in adults with uncomplicated plasmodium falciparum malaria.',
#   'URL': 'https://clinicaltrials.gov/study/nct03334747',
#   'Status': 'completed',
#   'Brief Summary': 'kae609 will be evaluated primarily for hepatic safety of single and multiple doses in sequential cohorts with increasing doses.this study aims to determine the maximum safe dose of the investigational drug kae609 in malaria patients.',
#   'Phase': 'phase2',
#   'Study Start Date': '2017-11-16',
#   'Expected Completion Date': '2019-11-23'},
#  'Drug/Intervention': {'Drug': ['kae609', 'coartem'],
#   'Procedure': [],
#   'Device': [],
#   'Behavioral': [],
#   'Combination_product': [],
#   'Biological': [],
#   'Radiation': [],
#   'Other': []},
#  'Disease/Condition': {'Disease Name': ['malaria']},
#  'Locations': [{'Institution': 'novartis investigative site',
#    'City': 'lambarene',
#    'Country': 'gabon'},
#   {'Institution': 'novartis investigative site',
#    'City': 'kintampo',
#    'Country': 'ghana'},
#   {'Institution': 'novartis investigative site',
#    'City': 'navrango',
#    'Country': 'ghana'},
#   {'Institution': 'novartis investigative site',
#    'City': 'bamako',
#    'Country': 'mali'},
#   {'Institution': 'novartis investigative site',
#    'City': 'sotuba',
#    'Country': 'mali'},
#   {'Institution': 'novartis investigative site',
#    'City': 'kigali',
#    'Country': 'rwanda'},
#   {'Institution': 'novartis investigative site',
#    'City': 'bushenyi',
#    'Country': 'uganda'},
#   {'Institution': 'novartis investigative site',
#    'City': 'kampala',
#    'Country': 'uganda'},
#   {'Institution': 'novartis investigative site',
#    'City': 'tororo',
#    'Country': 'uganda'}]}

# %%
len(json_data[:3])
# Out:
# 3

# %% [markdown]
# ### Load data into DB

# %%
# from neo4j import GraphDatabase

# class Neo4jGraphLoader:
#     def __init__(self, uri, user, password):
#         self.driver = GraphDatabase.driver(uri, auth=(user, password))

#     def close(self):
#         self.driver.close()

#     def load_json_into_graph(self, json_data):
#         with self.driver.session() as session:
#             for trial_data in json_data:
#                 print(f"Loading trial....{trial_data['Trial']['Trial ID']}")
#                 session.write_transaction(self._create_and_link_nodes, trial_data)

#     @staticmethod
#     def _create_and_link_nodes(tx, trial_data):
#         # Create or update the Trial node with all its attributes
#         trial_props = trial_data["Trial"]
#         tx.run("""
#             MERGE (trial:Trial {TrialID: $TrialID})
#             SET trial = $props
#             """, TrialID=trial_props["Trial ID"], props=trial_props)

#         # Create Intervention nodes and link to the Trial node
#         interventions = trial_data["Drug/Intervention"]
#         for intervention_type, intervention_names in interventions.items():
#             for name in intervention_names:
#                 tx.run("""
#                     MERGE (intervention:Intervention {Name: $name, Type: $type})
#                     WITH intervention
#                     MATCH (trial:Trial {TrialID: $TrialID})
#                     MERGE (trial)-[:USES]->(intervention)
#                     """, name=name, type=intervention_type, TrialID=trial_props["Trial ID"])

#         # Create Disease/Condition nodes and link to the Trial node
#         for disease_name in trial_data["Disease/Condition"]["Disease Name"]:
#             tx.run("""
#                 MERGE (disease:Disease {Name: $name})
#                 WITH disease
#                 MATCH (trial:Trial {TrialID: $TrialID})
#                 MERGE (trial)-[:TARGETS]->(disease)
#                 """, name=disease_name, TrialID=trial_props["Trial ID"])
            
#         for location in trial_data["Locations"]:
#             # Check if at least one attribute is present
#             if any(location.get(attr) for attr in ["Institution", "City", "Country"]):
#                 # Create or update Location node
#                 tx.run("""
#                     MERGE (location:Location {Institution: $institution, City: $city, Country: $country})
#                     ON CREATE SET location.Institution = $institution, location.City = $city, location.Country = $country
#                     ON MATCH SET location += {Institution: $institution, City: $city, Country: $country}
#                     WITH location
#                     MATCH (trial:Trial {TrialID: $TrialID})
#                     MERGE (trial)-[:CONDUCTED_AT]->(location)
#                     """, 
#                         institution=location.get("Institution", "Unknown"), 
#                         city=location.get("City", "Unknown"), 
#                         country=location.get("Country", "Unknown"), 
#                         TrialID=trial_data["Trial"]["Trial ID"])
#             else:
#                 print(f"Skipped a location due to insufficient data: {location}")

# %%
# Create an instance of the loader
json_path = r'config.json'
with open(json_path) as config_json:
    config = json.load(config_json)

# %%
from neo4j import GraphDatabase
uri = "neo4j+s://cf1b9b39.databases.neo4j.io" 
driver = GraphDatabase.driver(uri , auth = ("neo4j","vRDqUrdllXu6SkFA8vtxBk1bppbYHA-NFZc1mhjtgxY"))

# %%
NEO4J_URI=
NEO4J_USERNAME=neo4j
NEO4J_PASSWORD=vRDqUrdllXu6SkFA8vtxBk1bppbYHA-NFZc1mhjtgxY
AURA_INSTANCEID=cf1b9b39
AURA_INSTANCENAME=Instance01

# %%
def load_data_to_neo4j(data):
    with driver.session() as session:
        # Load Trial data
        trial_data = data["Trial"]
        trial_node = session.run("""
            MERGE (t:Trial {TrialID: $TrialID})
            ON CREATE SET t += $trial_data
            RETURN t
        """, TrialID=trial_data['Trial ID'], trial_data=trial_data).single()["t"]

        # Load Intervention data and connect to Trial
        interventions = data["Drug/Intervention"]
        for intervention_type, intervention_list in interventions.items():
            for intervention_name in intervention_list:
                intervention_node = session.run("""
                    MERGE (i:Intervention {Name: $Name, Type: $Type})
                    RETURN i
                """, Name=intervention_name, Type=intervention_type).single()["i"]
                session.run("""
                    MATCH (t:Trial {TrialID: $TrialID}), (i:Intervention {Name: $Name, Type: $Type})
                    MERGE (t)-[:USES]->(i)
                """, TrialID=trial_data['Trial ID'], Name=intervention_name, Type=intervention_type)

        # Load Disease/Condition data and connect to Trial
        for disease_name in data["Disease/Condition"]["Disease Name"]:
            disease_node = session.run("""
                MERGE (d:Disease {Name: $Name})
                RETURN d
            """, Name=disease_name).single()["d"]
            session.run("""
                MATCH (t:Trial {TrialID: $TrialID}), (d:Disease {Name: $Name})
                MERGE (t)-[:TARGETS]->(d)
            """, TrialID=trial_data['Trial ID'], Name=disease_name)

        # Load Location data and connect to Trial
        for location in data["Locations"]:
            location_node = session.run("""
                MERGE (l:Location {Institution: $Institution, City: $City, Country: $Country})
                RETURN l
            """, Institution=location["Institution"], City=location["City"], Country=location["Country"]).single()["l"]
            session.run("""
                MATCH (t:Trial {TrialID: $TrialID}), (l:Location {Institution: $Institution, City: $City, Country: $Country})
                MERGE (t)-[:CONDUCTED_AT]->(l)
            """, TrialID=trial_data['Trial ID'], Institution=location["Institution"], City=location["City"], Country=location["Country"])

# %%
for trial in json_data[:3]:
    load_data_to_neo4j(trial)
# Out:
# ---------------------------------------------------------------------------
# AuthError                                 Traceback (most recent call last)
# Cell In[78], line 2
#       1 for trial in json_data[:3]:
# ----> 2     load_data_to_neo4j(trial)
#
# Cell In[77], line 5, in load_data_to_neo4j(data)
#       2 with driver.session() as session:
#       3     # Load Trial data
#       4     trial_data = data["Trial"]
# ----> 5     trial_node = session.run("""
#       6         MERGE (t:Trial {TrialID: $TrialID})
#       7         ON CREATE SET t += $trial_data
#       8         RETURN t
#       9     """, TrialID=trial_data['Trial ID'], trial_data=trial_data).single()["t"]
#      11     # Load Intervention data and connect to Trial
#      12     interventions = data["Drug/Intervention"]
#
# File ~/opt/anaconda3/envs/tf_env/lib/python3.10/site-packages/neo4j/_sync/work/session.py:302, in Session.run(self, query, parameters, **kwargs)
#     299     self._auto_result._buffer_all()
#     301 if not self._connection:
# --> 302     self._connect(self._config.default_access_mode)
#     303     assert self._connection is not None
#     304 cx = self._connection
#
# File ~/opt/anaconda3/envs/tf_env/lib/python3.10/site-packages/neo4j/_sync/work/session.py:130, in Session._connect(self, access_mode, **acquire_kwargs)
#     128     access_mode = self._config.default_access_mode
#     129 try:
# --> 130     super()._connect(
#     131         access_mode, auth=self._config.auth, **acquire_kwargs
#     132     )
#     133 except asyncio.CancelledError:
#     134     self._handle_cancellation(message="_connect")
#
# File ~/opt/anaconda3/envs/tf_env/lib/python3.10/site-packages/neo4j/_sync/work/workspace.py:161, in Workspace._connect(self, access_mode, auth, **acquire_kwargs)
#     153     else:
#     154         # This is the first time we open a connection to a server in a
#     155         # cluster environment for this session without explicitly
#    (...)
#     158         # we shall use this database explicitly for all subsequent
#     159         # actions within this session.
#     160         log.debug("[#0000]  _: <WORKSPACE> resolve home database")
# --> 161         self._pool.update_routing_table(
#     162             database=self._config.database,
#     163             imp_user=self._config.impersonated_user,
#     164             bookmarks=self._get_bookmarks(),
#     165             auth=auth,
#     166             acquisition_timeout=acquisition_timeout,
#     167             database_callback=self._set_cached_database
#     168         )
#     169 acquire_kwargs_ = {
#     170     "access_mode": access_mode,
#     171     "timeout": acquisition_timeout,
#    (...)
#     175     "liveness_check_timeout": None,
#     176 }
#     177 acquire_kwargs_.update(acquire_kwargs)
#
# File ~/opt/anaconda3/envs/tf_env/lib/python3.10/site-packages/neo4j/_sync/io/_pool.py:774, in Neo4jPool.update_routing_table(self, database, imp_user, bookmarks, auth, acquisition_timeout, database_callback)
#     769 prefer_initial_routing_address = \
#     770     self.routing_tables[database].initialized_without_writers
#     772 if prefer_initial_routing_address:
#     773     # TODO: Test this state
# --> 774     if self._update_routing_table_from(
#     775         self.address, database=database,
#     776         imp_user=imp_user, bookmarks=bookmarks, auth=auth,
#     777         acquisition_timeout=acquisition_timeout,
#     778         database_callback=database_callback
#     779     ):
#     780         # Why is only the first initial routing address used?
#     781         return
#     782 if self._update_routing_table_from(
#     783     *(existing_routers - {self.address}), database=database,
#     784     imp_user=imp_user, bookmarks=bookmarks, auth=auth,
#     785     acquisition_timeout=acquisition_timeout,
#     786     database_callback=database_callback
#     787 ):
#
# File ~/opt/anaconda3/envs/tf_env/lib/python3.10/site-packages/neo4j/_sync/io/_pool.py:720, in Neo4jPool._update_routing_table_from(self, database, imp_user, bookmarks, auth, acquisition_timeout, database_callback, *routers)
#     716 for router in routers:
#     717     for address in NetworkUtil.resolve_address(
#     718         router, resolver=self.pool_config.resolver
#     719     ):
# --> 720         new_routing_table = self.fetch_routing_table(
#     721             address=address, acquisition_timeout=acquisition_timeout,
#     722             database=database, imp_user=imp_user, bookmarks=bookmarks,
#     723             auth=auth
#     724         )
#     725         if new_routing_table is not None:
#     726             new_database = new_routing_table.database
#
# File ~/opt/anaconda3/envs/tf_env/lib/python3.10/site-packages/neo4j/_sync/io/_pool.py:657, in Neo4jPool.fetch_routing_table(self, address, acquisition_timeout, database, imp_user, bookmarks, auth)
#     655 new_routing_info = None
#     656 try:
# --> 657     new_routing_info = self.fetch_routing_info(
#     658         address, database, imp_user, bookmarks, auth,
#     659         acquisition_timeout
#     660     )
#     661 except Neo4jError as e:
#     662     # checks if the code is an error that is caused by the client. In
#     663     # this case there is no sense in trying to fetch a RT from another
#     664     # router. Hence, the driver should fail fast during discovery.
#     665     if e._is_fatal_during_discovery():
#
# File ~/opt/anaconda3/envs/tf_env/lib/python3.10/site-packages/neo4j/_sync/io/_pool.py:625, in Neo4jPool.fetch_routing_info(self, address, database, imp_user, bookmarks, auth, acquisition_timeout)
#     623     auth = copy(auth)
#     624     auth.force_auth = False
# --> 625 cx = self._acquire(address, auth, deadline, None)
#     626 try:
#     627     routing_table = cx.route(
#     628         database=database or self.workspace_config.database,
#     629         imp_user=imp_user or self.workspace_config.impersonated_user,
#     630         bookmarks=bookmarks
#     631     )
#
# File ~/opt/anaconda3/envs/tf_env/lib/python3.10/site-packages/neo4j/_sync/io/_pool.py:313, in IOPool._acquire(self, address, auth, deadline, liveness_check_timeout)
#     308             raise ClientError(
#     309                 "failed to obtain a connection from the pool within "
#     310                 "{!r}s (timeout)".format(deadline.original_timeout)
#     311             )
#     312 log.debug("[#0000]  _: <POOL> trying to hand out new connection")
# --> 313 return connection_creator()
#
# File ~/opt/anaconda3/envs/tf_env/lib/python3.10/site-packages/neo4j/_sync/io/_pool.py:165, in IOPool._acquire_new_later.<locals>.connection_creator()
#     163 try:
#     164     try:
# --> 165         connection = self.opener(
#     166             address, auth or self.pool_config.auth, deadline
#     167         )
#     168     except ServiceUnavailable:
#     169         self.deactivate(address)
#
# File ~/opt/anaconda3/envs/tf_env/lib/python3.10/site-packages/neo4j/_sync/io/_pool.py:557, in Neo4jPool.open.<locals>.opener(addr, auth_manager, deadline)
#     556 def opener(addr, auth_manager, deadline):
# --> 557     return Bolt.open(
#     558         addr, auth_manager=auth_manager, deadline=deadline,
#     559         routing_context=routing_context, pool_config=pool_config
#     560     )
#
# File ~/opt/anaconda3/envs/tf_env/lib/python3.10/site-packages/neo4j/_sync/io/_bolt.py:487, in Bolt.open(cls, address, auth_manager, deadline, routing_context, pool_config)
#     485 connection.socket.set_deadline(deadline)
#     486 try:
# --> 487     connection.hello()
#     488 finally:
#     489     connection.socket.set_deadline(None)
#
# File ~/opt/anaconda3/envs/tf_env/lib/python3.10/site-packages/neo4j/_sync/io/_bolt5.py:579, in Bolt5x2.hello(self, dehydration_hooks, hydration_hooks)
#     577 self.logon(dehydration_hooks, hydration_hooks)
#     578 self.send_all()
# --> 579 self.fetch_all()
#     580 check_supported_server_product(self.server_info.agent)
#
# File ~/opt/anaconda3/envs/tf_env/lib/python3.10/site-packages/neo4j/_sync/io/_bolt.py:863, in Bolt.fetch_all(self)
#     861 response = self.responses[0]
#     862 while not response.complete:
# --> 863     detail_delta, summary_delta = self.fetch_message()
#     864     detail_count += detail_delta
#     865     summary_count += summary_delta
#
# File ~/opt/anaconda3/envs/tf_env/lib/python3.10/site-packages/neo4j/_sync/io/_bolt.py:849, in Bolt.fetch_message(self)
#     845 # Receive exactly one message
#     846 tag, fields = self.inbox.pop(
#     847     hydration_hooks=self.responses[0].hydration_hooks
#     848 )
# --> 849 res = self._process_message(tag, fields)
#     850 self.idle_since = perf_counter()
#     851 return res
#
# File ~/opt/anaconda3/envs/tf_env/lib/python3.10/site-packages/neo4j/_sync/io/_bolt5.py:374, in Bolt5x0._process_message(self, tag, fields)
#     372 self._server_state_manager.state = self.bolt_states.FAILED
#     373 try:
# --> 374     response.on_failure(summary_metadata or {})
#     375 except (ServiceUnavailable, DatabaseUnavailable):
#     376     if self.pool:
#
# File ~/opt/anaconda3/envs/tf_env/lib/python3.10/site-packages/neo4j/_sync/io/_common.py:281, in LogonResponse.on_failure(self, metadata)
#     279 handler = self.handlers.get("on_summary")
#     280 Util.callback(handler)
# --> 281 raise Neo4jError.hydrate(**metadata)
#
# AuthError: {code: Neo.ClientError.Security.Unauthorized} {message: The client is unauthorized due to authentication failure.}
